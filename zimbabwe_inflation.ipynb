# %%
# Highest monthly inflation: 79,600,000,000%
# Prices doubled every: 24.7 hours
#  monthly inflation rate of approximately 79 billion percent

# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
# will need to run: pip install quandl
import quandl
import plotly.express as px
import plotly.graph_objects as go

import matplotlib.ticker as mtick

# %%
days = 31
cpi_ex = 100

cpi_array = [100]


for x in range(days):
    cpi_ex = cpi_ex * 2
#     print(f"cpis {x} = {cpi_ex}") 
    
    cpi_array.append(cpi_ex)
    
#     cpis_day = "cpis "+ str(x)
    
#     next_day_df = pd.DataFrame({:[cpi_ex]})
    
#     Zimbabwe_df.append( next_day_df, ignore_index = True)
Zimbabwe_df = pd.DataFrame({"cpi_amount":cpi_array})
Zimbabwe_df.set_index(['cpi_amount'])

Zimbabwe_df.head(30)
# Out:
#      cpi_amount
# 0           100
# 1           200
# 2           400
# 3           800
# 4          1600
# 5          3200
# 6          6400
# 7         12800
# 8         25600
# 9         51200
# 10       102400
# 11       204800
# 12       409600
# 13       819200
# 14      1638400
# 15      3276800
# 16      6553600
# 17     13107200
# 18     26214400
# 19     52428800
# 20    104857600
# 21    209715200
# 22    419430400
# 23    838860800
# 24   1677721600
# 25   3355443200
# 26   6710886400
# 27  13421772800
# 28  26843545600
# 29  53687091200

# %%
# After we are done we could use a heat to see, the corrlation between inflations and our other test factore

# %%
ax = Zimbabwe_df.plot.bar( rot=0, figsize=(15,5))

ax.yaxis.set_major_formatter(mtick.PercentFormatter())
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\44nas\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Out:
#             Value
# Date
# 2016-04-01  5.782
# 2016-07-01  5.715
# 2016-10-01  5.692
# 2017-01-01  5.622
# 2017-04-01  5.545
# 2017-07-01  5.508
# 2017-10-01  5.512
# 2018-01-01  5.533
# 2018-04-01  5.634
# 2018-07-01  5.634
# 2018-10-01  5.600
# 2019-01-01  5.604
# 2019-04-01  5.633
# 2019-07-01  5.582
# 2019-10-01  5.486
# 2020-01-01  5.247
# 2020-04-01  1.555
# 2020-07-01  1.248
# 2020-10-01  1.221
# 2021-01-01  1.198

# %%
# Out:
#             Value
# Date
# 2016-04-01  1.461
# 2016-07-01  1.452
# 2016-10-01  1.445
# 2017-01-01  1.439
# 2017-04-01  1.432
# 2017-07-01  1.435
# 2017-10-01  1.444
# 2018-01-01  1.454
# 2018-04-01  1.461
# 2018-07-01  1.461
# 2018-10-01  1.463
# 2019-01-01  1.457
# 2019-04-01  1.453
# 2019-07-01  1.441
# 2019-10-01  1.426
# 2020-01-01  1.379
# 2020-04-01  1.103
# 2020-07-01  1.148
# 2020-10-01  1.135
# 2021-01-01  1.123
