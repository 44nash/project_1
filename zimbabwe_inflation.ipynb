# %%
# Highest monthly inflation: 79,600,000,000%
# Prices doubled every: 24.7 hours
#  monthly inflation rate of approximately 79 billion percent

# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
# will need to run: pip install quandl
import quandl
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits import mplot3d
from random import randrange
from matplotlib.pyplot import figure
import random
import matplotlib.ticker as mtick

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
days = 31
cpi_ex = 100

cpi_array = [100]

velocity_ex =[5]


for x in range(days):
    cpi_ex = cpi_ex * 2 
    cpi_array.append(cpi_ex)
    
    velocity_ex.append(random.uniform(10.5, 14.1))
    
Zimbabwe_df = pd.DataFrame({"cpi_amount":cpi_array, "velocity": velocity_ex})
Zimbabwe_df.set_index(['cpi_amount'])

Zimbabwe_df.head(30)
# Out:
#      cpi_amount   velocity
# 0           100   5.000000
# 1           200  13.953412
# 2           400  10.945893
# 3           800  13.143473
# 4          1600  10.654574
# 5          3200  13.854398
# 6          6400  12.371658
# 7         12800  11.026382
# 8         25600  13.253194
# 9         51200  12.891088
# 10       102400  11.806376
# 11       204800  10.744458
# 12       409600  13.315174
# 13       819200  13.109521
# 14      1638400  13.153670
# 15      3276800  11.113687
# 16      6553600  12.161445
# 17     13107200  13.785786
# 18     26214400  11.993979
# 19     52428800  10.517295
# 20    104857600  13.411863
# 21    209715200  11.975066
# 22    419430400  11.289213
# 23    838860800  12.211356
# 24   1677721600  14.098157
# 25   3355443200  12.289992
# 26   6710886400  12.084782
# 27  13421772800  11.945217
# 28  26843545600  13.238046
# 29  53687091200  11.240060

# %%
# After we are done we could use a heat to see, the corrlation between inflations and our other test factore

# %%
ax = Zimbabwe_df.plot.bar( rot=0, figsize=(15,5))

ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
# zdata = 15 * np.random.random(100)
# xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
# ydata = np.cos(zdata) + 0.1 * np.random.randn(100)

zdata = Zimbabwe_df.cpi_amount 
xdata = Zimbabwe_df.index
ydata = Zimbabwe_df.velocity



ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

figure(figsize=(15, 7), dpi=80)

ax.set_zlabel('cpi_amount')
ax.set_xlabel('time')
ax.set_ylabel('velocity')


# ax.view_init(60, 35)
# fig
# Out:
# Text(0.5, 0, 'velocity')

# %%
ax = plt.axes(projection='3d')
ax.view_init(60, 35)
ax.scatter(xdata, ydata, zdata, c=zdata, cmap='viridis', linewidth=0.5);

# %%
ax = plt.axes(projection='3d')
ax.scatter(xdata, ydata, zdata, c=zdata, cmap='viridis', linewidth=0.5);
