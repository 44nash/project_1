# %%
# imports - just pulled from the rental analysis homework
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv
import requests
import json

import warnings
warnings.filterwarnings('ignore')

# %%
#Tyler FRED API
#.gitignore file under Tyler_Keys

load_dotenv('Tyler_Keys/Tyler_Keys.env')
Tyler_FRED_API = os.getenv("FRED")
print(Tyler_FRED_API)
# Out:
# d7bd1dd8eb442bf7a65c1ff5c20a0b4e

# %%
# I couldn't figure out the API but will keep working on it.
# https://api.stlouisfed.org/fred/series/observations?series_id=GNPCA&api_key=abcdefghijklmnopqrstuvwxyz123456
#https://fred.stlouisfed.org/docs/api/fred/series_observations.html



# https://api.stlouisfed.org/fred/series/observations?series_id=GNPCA&api_key=abcdefghijklmnopqrstuvwxyz123456&file_type=json
api_url = "https://api.stlouisfed.org/fred/series/observations?series_id=GNPCA&api_key="+Tyler_FRED_API+"&file_type=json"


# response_data = requests.get(request_url).json()
# print(json.dumps(response_data, indent=4))

fred_api_response_data = requests.get(api_url).json()
# print(fred_api_response_data)
print(json.dumps(fred_api_response_data, indent=4))
# Out:
# {
#     "realtime_start": "2021-05-06",
#     "realtime_end": "2021-05-06",
#     "observation_start": "1600-01-01",
#     "observation_end": "9999-12-31",
#     "units": "lin",
#     "output_type": 1,
#     "file_type": "json",
#     "order_by": "observation_date",
#     "sort_order": "asc",
#     "count": 92,
#     "offset": 0,
#     "limit": 100000,
#     "observations": [
#         {
#             "realtime_start": "2021-05-06",
#             "realtime_end": "2021-05-06",
#             "date": "1929-01-01",
#             "value": "1120.076"
#         },
#         {
#             "realtime_start": "2021-05-06",
#             "realtime_end": "2021-05-06",
#             "date": "1930-01-01",
#             "value": "1025.091"
#         },
#         {
#             "realtime_start": "2021-05-06",
#             "realtime_end": "2021-05-06",
#             "date": "1931-01-01",
#             "value": "958.378"
#         },
#         {
#             "realtime_start": "2021-05-06",
# ...

# %%
data_df = pd.DataFrame(fred_api_response_data)
data_df.head(10)
# Out:
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 1     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 2     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 3     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 4     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 5     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 6     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 7     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 8     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
# 9     2021-05-06   2021-05-06        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc     92       0  100000
# ...

# %%
#PPI - Monthly

file_path = Path("Excel_Data/PPI.csv")
PPI_data = pd.read_csv(file_path, index_col="DATE")
PPI_data.head()
# Out:
#         PPIACO
# DATE
# 1/1/13    12.1
# 2/1/13    12.0
# 3/1/13    12.0
# 4/1/13    12.0
# 5/1/13    11.9

# %%
#U.S Individual Income Tax: Tax Rates for Regular Tax: Lowest Bracket - Yearly

file_path = Path("Excel_Data/ITBLB.csv")
Individual_Tax_Lower_data = pd.read_csv(file_path, index_col="YEAR")
Individual_Tax_Lower_data.head()
# Out:
#         IITTRLB
# YEAR
# 1/1/13      1.0
# 1/1/14      1.0
# 1/1/15      1.0
# 1/1/16      2.0
# 1/1/17      2.0

# %%
#U.S Individual Income Tax: Tax Rates for Regular Tax: Highest Bracket - Yearly

file_path = Path("Excel_Data/ITBHB.csv")
Individual_Tax_Lower_data = pd.read_csv(file_path, index_col="YEAR")
Individual_Tax_Lower_data.head()
# Out:
#         IITTRHB
# YEAR
# 1/1/13      7.0
# 1/1/14      7.0
# 1/1/15      7.0
# 1/1/16     15.0
# 1/1/17     67.0

# %%
#Total Liabilties - Monthly

file_path = Path("Excel_Data/Total_Liabilities.csv")
Individual_Tax_Lower_data = pd.read_csv(file_path, index_col="Month")
Individual_Tax_Lower_data.head()
# Out:
#             LTOTL
# Month
# 11/20/14  229.100
# 11/27/14  251.968
# 12/4/14   255.037
# 12/11/14  254.429
# 12/18/14  251.940
